# %% [markdown]
# El tipo de datos integer permite representar números enteros, al darse un número con decimales éste lo convierte a número entero. Se representa como int.

# %%
#ejemplo de integer
int(4.0)
# Out:
# 4

# %%
#ejemplo de integer
int(4.3459)
# Out:
# 4

# %%
#ejemplo de integer
int(4.9)
# Out:
# 4

# %% [markdown]
# Los datos float por el contrario de los integer si poseen decimales. Se representa como float

# %%
#ejemplo de float
float(7.94)
# Out:
# 7.94

# %%
#ejemplo de float
float(6.0)
# Out:
# 6.0

# %% [markdown]
# Un string es una secuencia de caracteres, por ejemplo, el abecedario tiene 27 letras, ese sería su string, en el caso de Python pueden ser caracteres cualesquiera. Se representa como str

# %%
#ejemplo de string
str ("abcde")
# Out:
# 'abcde'

# %%
#ejemplo de string
str (12345)
# Out:
# '12345'

# %%
#ejemplo de string
str('a1b2c3d4e5')
# Out:
# 'a1b2c3d4e5'

# %% [markdown]
# Sumas

# %%
int(2+2)
# Out:
# 4

# %%
float(4.5+5.3)
# Out:
# 9.8

# %% [markdown]
# Restas

# %%
int(6-4)
# Out:
# 2

# %%
float(5.60-4.60)
# Out:
# 1.0

# %% [markdown]
# Multiplicación

# %%
int(6*3)
# Out:
# 18

# %%
float(5.3*2.7)
# Out:
# 14.31

# %% [markdown]
# División

# %%
int(8/2)
# Out:
# 4

# %%
float(6.6/2.4)
# Out:
# 2.75

# %% [markdown]
# División entera

# %%
int(12//3)
# Out:
# 4

# %%
float(8.4//3.2)
# Out:
# 2.0

# %% [markdown]
# Módulo

# %%
int(6%5)
# Out:
# 1

# %%
float(7.6%3.8)
# Out:
# 0.0

# %% [markdown]
# Potencias

# %%
int(2**3)
# Out:
# 8

# %%
float(2.5**2.1)
# Out:
# 6.849738914907609

# %% [markdown]
# La concatenación sirve para unir dos o más strings.

# %%
#ejemplo de concatenación de strings
a= ("hola")
b= (" a todos")
str (a+b)
# Out:
# 'hola a todos'

# %% [markdown]
# Type funciona para saber con que tipo de dato estamos trabajando.

# %%
type(8.32)
# Out:
# float

# %% [markdown]
# Print imprime lo que queramos que se diga o se muestre.

# %%
print ('hola a todos')
# Out:
# hola a todos

# %% [markdown]
# Input define un espacio para que el usuario pueda agregar información.

# %%
input("¿Cuál es su edad?")

# %% [markdown]
# Int significa un número entero.

# %%
int(4)
# Out:
# 4

# %% [markdown]
# Float indica que puede ser un número con decimales.

# %%
float(2.33)
# Out:
# 2.33

# %% [markdown]
# Str significa un conjunto de caracteres.

# %%
str('a2h7m9')
# Out:
# 'a2h7m9'

# %%
#Pasar de grados Celsius a Fahrenheit
print ('Bienvenido a su programa para pasar de grados Celsius a Fahrenheit')
c= int (input('Ingrese la temperatura en grados celsius: '))
d=c*9/5+32
e=('La temperatura en grados Fahrenheit es:')
print(e,d,)
# Out:
# Bienvenido a su programa para pasar de grados Celsius a Fahrenheit
# Ingrese la temperatura en grados celsius: 56
# La temperatura en grados Fahrenheit es: 132.8

# %%
#Cálculo del área y el perímetro de un rectángulo
print ('Bienvenido a su programa para calcular el área y el perímetro de un rectángulo')
altura=int(input('Ingrese la medida de la altura en metros : '))
base=int(input('Ingrese la medida de la base en metros: '))
f='El área correponde a:'
g='El perímetro corresponde a:'
area= base*altura
perimetro= 2*base+2*altura
print (f, area,"m2")
print(g, perimetro,"m")
# Out:
# Bienvenido a su programa para calcular el área y el perímetro de un rectángulo
# Ingrese la medida de la altura en metros : 2
# Ingrese la medida de la base en metros: 4
# El área correponde a: 8 m2
# El perímetro corresponde a: 12 m

# %%
#Cálculo del área y del perímetro de un círculo
print('Bienvenido a su programa para calcular el área y perímetro de un círculo')
radio=float(input('Ingrese la medida del radio del círculo: '))
from math import pi 
area=float(pi*radio*radio)
perimetro=2*pi*radio
h="El área del círculo es:"
i="El perímetro del círculo es:"
print(h,area)
print(i,perimetro)
# Out:
# Bienvenido a su programa para calcular el área y perímetro de un círculo
# Ingrese la medida del radio del círculo: 4
# El área del círculo es: 50.26548245743669
# El perímetro del círculo es: 25.132741228718345
